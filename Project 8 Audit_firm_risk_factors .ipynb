# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
audit=pd.read_csv(r'C:\Users\HP\Downloads\Audit_firm_risk_factors.csv')

# %%
audit.head()
# Out:
#    Unnamed: 0  PARA_A  PARA_B  TOTAL  Sector_score  numbers  LOSS_SCORE  \
# 0           0    4.18    2.50   6.68          3.89      5.0           2
# 1           1    0.00    4.83   4.83          3.89      5.0           2
# 2           2    0.51    0.23   0.74          3.89      5.0           2
# 3           3    0.00   10.80  10.80          3.89      6.0           2
# 4           4    0.00    0.08   0.08          3.89      5.0           2
#
#    Money_Value  History_score  District  Risk
# 0         3.38              2         2     1
# 1         0.94              2         2     0
# 2         0.00              2         2     0
# 3        11.75              2         2     1
# 4         0.00              2         2     0

# %%
audit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776 entries, 0 to 775
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     776 non-null    int64
#  1   PARA_A         776 non-null    float64
#  2   PARA_B         776 non-null    float64
#  3   TOTAL          776 non-null    float64
#  4   Sector_score   776 non-null    float64
#  5   numbers        776 non-null    float64
#  6   LOSS_SCORE     776 non-null    int64
#  7   Money_Value    775 non-null    float64
#  8   History_score  776 non-null    int64
#  9   District       776 non-null    int64
#  10  Risk           776 non-null    int64
# dtypes: float64(6), int64(5)
# memory usage: 66.8 KB

# %%
audit.describe()
# Out:
#        Unnamed: 0      PARA_A       PARA_B        TOTAL  Sector_score  \
# count  776.000000  776.000000   776.000000   776.000000    776.000000
# mean   387.500000    2.450194    10.799988    13.218481     20.184536
# std    224.156196    5.678870    50.083624    51.312829     24.319017
# min      0.000000    0.000000     0.000000     0.000000      1.850000
# 25%    193.750000    0.210000     0.000000     0.537500      2.370000
# 50%    387.500000    0.875000     0.405000     1.370000      3.890000
# 75%    581.250000    2.480000     4.160000     7.707500     55.570000
# max    775.000000   85.000000  1264.630000  1268.910000     59.850000
#
#           numbers  LOSS_SCORE  Money_Value  History_score    District  \
# count  776.000000  776.000000   775.000000     776.000000  776.000000
# mean     5.067655    2.061856    14.137631       2.167526    2.505155
# std      0.264449    0.375080    66.606519       0.679869    1.228678
# ...

# %%
audit.isnull().sum()
# Out:
# Unnamed: 0       0
# PARA_A           0
# PARA_B           0
# TOTAL            0
# Sector_score     0
# numbers          0
# LOSS_SCORE       0
# Money_Value      1
# History_score    0
# District         0
# Risk             0
# dtype: int64

# %%
audit["Money_Value"]=audit["Money_Value"].fillna(14.13)

# %%
audit.columns
# Out:
# Index(['Unnamed: 0', 'PARA_A', 'PARA_B', 'TOTAL', 'Sector_score', 'numbers',
#        'LOSS_SCORE', 'Money_Value', 'History_score', 'District', 'Risk'],
#       dtype='object')

# %%
audit
# Out:
#      Unnamed: 0  PARA_A  PARA_B  TOTAL  Sector_score  numbers  LOSS_SCORE  \
# 0             0    4.18    2.50   6.68          3.89      5.0           2
# 1             1    0.00    4.83   4.83          3.89      5.0           2
# 2             2    0.51    0.23   0.74          3.89      5.0           2
# 3             3    0.00   10.80  10.80          3.89      6.0           2
# 4             4    0.00    0.08   0.08          3.89      5.0           2
# ..          ...     ...     ...    ...           ...      ...         ...
# 771         771    0.49    0.40   0.89         55.57      5.0           2
# 772         772    0.47    0.37   0.84         55.57      5.0           2
# 773         773    0.24    0.04   0.28         55.57      5.0           2
# 774         774    0.20    0.00   0.20         55.57      5.0           2
# 775         775    0.00    0.00   0.00         55.57      5.0           2
#
#      Money_Value  History_score  District  Risk
# ...

# %%
audit["PARA_A"]
# Out:
# 0      4.18
# 1      0.00
# 2      0.51
# 3      0.00
# 4      0.00
#        ...
# 771    0.49
# 772    0.47
# 773    0.24
# 774    0.20
# 775    0.00
# Name: PARA_A, Length: 776, dtype: float64

# %%
plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
sns.distplot(x=audit["PARA_A"])
plt.subplot(1,2,2)
sns.distplot(x=audit["PARA_B"])
plt.show()

# %%
abs(audit.corr())
# Out:
#                Unnamed: 0    PARA_A    PARA_B     TOTAL  Sector_score  \
# Unnamed: 0       1.000000  0.209933  0.181046  0.200235      0.816894
# PARA_A           0.209933  1.000000  0.161940  0.267042      0.216824
# PARA_B           0.181046  0.161940  1.000000  0.994100      0.132670
# TOTAL            0.200235  0.267042  0.994100  1.000000      0.153316
# Sector_score     0.816894  0.216824  0.132670  0.153316      1.000000
# numbers          0.179956  0.133786  0.209855  0.217641      0.151840
# LOSS_SCORE       0.086895  0.043707  0.042551  0.046471      0.086750
# Money_Value      0.157123  0.449274  0.125029  0.168662      0.117429
# History_score    0.199047  0.172635  0.316541  0.326396      0.136900
# District         0.009726  0.127804  0.082944  0.093342      0.108202
# Risk             0.345155  0.292425  0.162807  0.190793      0.374588
#
#                 numbers  LOSS_SCORE  Money_Value  History_score  District  \
# ...

# %%
def correlation_plot(df):
    
    corr = abs(df.corr()) # correlation matrix
    lower_triangle = np.tril(corr, k = -1)  # select only the lower triangle of the correlation matrix
    mask = lower_triangle == 0  # to mask the upper triangle in the following heatmap

    plt.figure(figsize = (15,10))  # setting the figure size
    sns.set_style(style = 'white')  # Setting it to white so that we do not see the grid lines
    sns.heatmap(lower_triangle, center=0.5, cmap= 'Blues', xticklabels = corr.index,
                yticklabels = corr.columns,cbar = False, annot= True, linewidths= 1, mask = mask)   # Da Heatmap
    plt.show()
    
correlation_plot(audit)

# %%
# 'TOTAL' and 'PARA_B' have almost a 100% correlation
# Let's drop 'TOTAL'

# %%
audit.drop('TOTAL',axis=1,inplace=True)

# %%
audit["LOSS_SCORE"].value_counts()
# Out:
# LOSS_SCORE
# 2    754
# 4     20
# 6      2
# Name: count, dtype: int64

# %%
sns.countplot(data=audit,x='LOSS_SCORE')
plt.show()

# %%
audit["History_score"].value_counts()
# Out:
# History_score
# 2    726
# 4     35
# 6     15
# Name: count, dtype: int64

# %%
sns.countplot(data=audit,x='History_score')
plt.show()

# %%
audit["District"].value_counts()
# Out:
# District
# 2    653
# 6     73
# 4     50
# Name: count, dtype: int64

# %%
sns.countplot(data=audit,x='District')
plt.show()

# %%
audit
# Out:
#      Unnamed: 0  PARA_A  PARA_B  Sector_score  numbers  LOSS_SCORE  \
# 0             0    4.18    2.50          3.89      5.0           2
# 1             1    0.00    4.83          3.89      5.0           2
# 2             2    0.51    0.23          3.89      5.0           2
# 3             3    0.00   10.80          3.89      6.0           2
# 4             4    0.00    0.08          3.89      5.0           2
# ..          ...     ...     ...           ...      ...         ...
# 771         771    0.49    0.40         55.57      5.0           2
# 772         772    0.47    0.37         55.57      5.0           2
# 773         773    0.24    0.04         55.57      5.0           2
# 774         774    0.20    0.00         55.57      5.0           2
# 775         775    0.00    0.00         55.57      5.0           2
#
#      Money_Value  History_score  District  Risk
# 0           3.38              2         2     1
# 1           0.94              2         2     0
# ...

# %%
x= audit.drop("Risk",axis=1)

# %%
y=audit["Risk"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score,KFold

# %%
k=KFold(n_splits=4)

# %%
list=[LogisticRegression,DecisionTreeClassifier,RandomForestClassifier,SVC,KNeighborsClassifier]

# %%
for i in list:
    model=i()
    print(model)
    print(cross_val_score(model,x_train,y_train,cv=k).mean())
# Out:
# LogisticRegression()
# 0.9548387096774194
# DecisionTreeClassifier()
# 0.9838709677419355
# RandomForestClassifier()
# 0.982258064516129
# SVC()
# 0.6983870967741935
# KNeighborsClassifier()
# 0.7435483870967742

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
dt=DecisionTreeClassifier(random_state=1)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
dt.score(x_test,y_test)
# Out:
# 0.9807692307692307

# %%
plot_tree(dt)
plt.show()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,dt.predict(x_test))
# Out:
# 0.9807692307692307

# %%
sns.heatmap(confusion_matrix(y_test,dt.predict(x_test)),annot=True)
plt.show()

# %%
print(classification_report(y_test,dt.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        59
#            1       0.97      1.00      0.98        97
#
#     accuracy                           0.98       156
#    macro avg       0.98      0.97      0.98       156
# weighted avg       0.98      0.98      0.98       156
